# %%
from web3 import Web3, HTTPProvider
connection = Web3(HTTPProvider('https://mainnet.infura.io/v3/134027dbcc8b4ec6ac2a56e4a9a30c85'))
print ("Latest Ethereum block number", connection.eth.blockNumber)
# Out:
# Latest Ethereum block number 14956669

# %%
connection.isConnected()
# Out:
# True

# %%
connection.eth.get_balance('0x2559BDb6346614c08b0B9c8b5225555247fA2050')/10**18
# Out:
# 5.123071988930125

# %%
connection

# %%
connection.eth.get_block('latest')
# Out:
# AttributeDict({'baseFeePerGas': 125998597435,
#  'difficulty': 14268154343391534,
#  'extraData': HexBytes('0x617369612d65617374322d31763932'),
#  'gasLimit': 30029295,
#  'gasUsed': 30008822,
#  'hash': HexBytes('0x257d02fe678fae2e431e15b4033d402b65f4cbe7473326cc2cdf8ed681dd6067'),
#  'logsBloom': HexBytes('...'),
#  'miner': '0xEA674fdDe714fd979de3EdF0F56AA9716B898ec8',
#  'mixHash': HexBytes('0x680403dcf3c3165f0b2ca35db88ce2311e5638e91afa747a0c73ef5639841e1b'),
#  'nonce': HexBytes('0xdd91c2c5fafa672f'),
#  'number': 14956706,
#  'parentHash': HexBytes('0x78d7634e956e610086b85c0ab3327362eecfc8f6d28507f645d837dca65544b1'),
#  'receiptsRoot': HexBytes('0x2a56728d78cde327b62d4a41d8a875a420ef3a71cd9e0040b2f93f9c176ed215'),
#  'sha3Uncles': HexBytes('0x2b45b4c19bb8f1738e9fc1c2af446248241f78feee1ee6867d202a650cd172a5'),
#  'size': 158569,
#  'stateRoot': HexBytes('0xb7140bfbe2e972e3fed6b7410a7ab39056bb0a646a17c4d3439dfa2114899a65'),
#  'timestamp': 1655134204,
# ...
