# %%
import pandas as pd

# %%
pd.read_excel('../database/export_binance/miguel_merged.xlsx', index_col=0)
# Out:
#       User_ID             UTC_Time       Account          Operation  Coin  \
# 0    11351073  2021-04-23 08:05:00          Spot            Deposit   EUR
# 1    11351073  2021-05-18 10:27:11          Spot  Large OTC trading   EUR
# 2    11351073  2021-05-18 10:27:11          Spot  Large OTC trading   BTC
# 3    11351073  2021-05-22 09:01:55          Spot            Deposit   EUR
# 4    11351073  2021-05-22 09:05:23          Spot  Large OTC trading   BTC
# ..        ...                  ...           ...                ...   ...
# 766  11351073  2022-05-31 00:00:00  USDT-Futures        Funding Fee  USDT
# 767  11351073  2022-05-31 02:16:36          Spot       Distribution  LUNA
# 768  11351073  2022-05-31 08:00:00  USDT-Futures        Funding Fee  USDT
# 769  11351073  2022-05-31 16:00:00  USDT-Futures        Funding Fee  USDT
# 770  11351073  2022-05-31 18:13:08          Spot            Deposit  LUNA
#
#         Change Remark
# 0    49.100000    NaN
# 1   -49.100000    NaN
# ...

# %%
pd.read_excel('../database/export_binance/df_new.xlsx', index_col=0).dtypes
# Out:
# /var/folders/yl/s1pq6fh930j3frb4n30yfhv00000gn/T/ipykernel_92593/785665653.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   pd.read_excel('../database/export_binance/df_new.xlsx', index_col=0).dtypes
# User_ID               int64
# UTC_Time     datetime64[ns]
# Account              object
# Operation            object
# Coin                 object
# Change              float64
# Remark               object
# dtype: object

# %%
pd.read_excel('../database/prices/historical_prices_miguel.xlsx').dtypes
# Out:
# datetime     datetime64[ns]
# EURUSDT             float64
# BTCUSDT             float64
# ETHUSDT             float64
# BNBUSDT             float64
# BUSDUSDT            float64
# ONGUSDT             float64
# ONTUSDT             float64
# AXSUSDT             float64
# SLPUSDT             float64
# SOLUSDT             float64
# LUNAUSDT            float64
# MATICUSDT           float64
# ADAUSDT             float64
# USTUSDT             float64
# ROSEUSDT            float64
# JASMYUSDT           float64
# dtype: object

# %%
df_hist_prices = pd.read_excel('../database/prices/historical_prices.xlsx')

# %%
df_hist_prices_copy = df_hist_prices.copy()

# %%
df_hist_prices_copy
# Out:
#       datetime  SOLUSDT   BTCUSDT   BNBUSDT  BUSDUSDT  LTCUSDT  EURUSDT  \
# 0   2021-01-01   1.8421  29331.69   37.7762    0.9973   126.24   1.2183
# 1   2021-01-02   1.7999  32178.33   38.2331    0.9989   136.96   1.2412
# 2   2021-01-03   2.1779  33000.05   41.2575    0.9979   161.24   1.2594
# 3   2021-01-04   2.4909  31988.71   41.1333    0.9993   155.34   1.2286
# 4   2021-01-05   2.1636  33949.53   41.8219    0.9969   158.43   1.2274
# ..         ...      ...       ...       ...       ...      ...      ...
# 511 2022-05-27  41.1700  28629.80  301.6000    1.0013    61.60   1.0740
# 512 2022-05-28  44.2500  29031.33  307.5000    1.0010    63.00   1.0730
# 513 2022-05-29  44.9800  29468.10  305.8000    1.0011    63.60   1.0720
# 514 2022-05-30  47.2200  31734.22  321.8000    1.0007    69.10   1.0770
# 515 2022-05-31  45.7700  31801.04  320.9000    1.0007    68.40   1.0740
#
#      LINKUSDT  AVAXUSDT  MATICUSDT  ...  CAKEUSDT  DOTUSDT  BETAUSDT  \
# ...
